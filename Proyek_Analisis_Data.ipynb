# %% [markdown]
# # Proyek Analisis Data: [Bike Sharing Dataset]
# - **Nama:** Simiao S. da Gama
# - **Email:** simiao.alnuco@gmail.com
# - **ID Dicoding:** simiao

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1
# - Pertanyaan 2

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /home/alnuco/python_env/lib/python3.10/site-packages (1.39.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: numpy<3,>=1.20 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (1.25.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: requests<3,>=2.27 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (3.1.32)
# Requirement already satisfied: click<9,>=7.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: watchdog<6,>=2.1.5 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (5.0.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: packaging<25,>=20 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (23.1)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (13.9.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (10.0.0)
# Requirement already satisfied: altair<6,>=4.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: jinja2 in /home/alnuco/python_env/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.18.4)
# Requirement already satisfied: narwhals>=1.5.2 in /home/alnuco/python_env/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (1.10.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/alnuco/python_env/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /home/alnuco/python_env/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alnuco/python_env/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/alnuco/python_env/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.1.1)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.9.2)
# Requirement already satisfied: referencing>=0.28.4 in /home/alnuco/python_env/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/alnuco/python_env/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/alnuco/python_env/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: mdurl~=0.1 in /home/alnuco/python_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/alnuco/python_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
from babel.numbers import format_currency

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
df_day = pd.read_csv("Bike Sharing Dataset/day.csv")
df_day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
df_hour = pd.read_csv("Bike Sharing Dataset/hour.csv")
df_hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %%
print(df_hour.columns)
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt', 'weather'],
#       dtype='object')

# %%
print(df_day.columns)
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt', 'weather'],
#       dtype='object')

# %%
print(df_day[3,4])

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ### Menilai Tabel Day

# %%
df_day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# ##### Check Missing Vales on Day.csv

# %%
df_day.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah Duplikasi di Tabel Day.csv : ", df_day.duplicated().sum())
# Out:
# Jumlah Duplikasi di Tabel Day.csv :  0

# %%
df_day.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# ### Menilai Tabel Hour

# %%
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# #### Check Missing Value on Tabel hour

# %%
df_hour.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah Data Duplicated di tabel Hour : ", df_hour.duplicated().sum())
# Out:
# Jumlah Data Duplicated di tabel Hour :  0

# %%
df_hour.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Karena tidak duplicated data dan missing value untuk data day dan hour maka kita tidak gunakan cleaning data

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore df_day

# %%
df_day.sample(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 78        79  2011-03-20       1   0     3        0        0           0
# 385      386  2012-01-21       1   1     1        0        6           0
# 694      695  2012-11-25       4   1    11        0        0           0
# 625      626  2012-09-17       3   1     9        0        1           1
# 225      226  2011-08-14       3   0     8        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 78            1  0.332500  0.325750  0.473750   0.207721    1047        1424
# 385           2  0.173333  0.174875  0.831250   0.222642      67        1234
# 694           1  0.245833  0.257583  0.468333   0.150500     309        2115
# 625           2  0.580833  0.553050  0.734583   0.151742    1022        5847
# 225           2  0.676667  0.624388  0.817500   0.222633    1338        2482
#
#       cnt
# 78   2471
# 385  1301
# 694  2424
# 625  6869
# 225  3820

# %%
df_day.describe(include="all")
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-01-01         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.028728    2.997264    0.683995    1.395349    0.495385
# std       0.167155    2.004787    0.465233    0.544894    0.183051
# min       0.000000    0.000000    0.000000    1.000000    0.059130
# 25%       0.000000    1.000000    0.000000    1.000000    0.337083
# 50%       0.000000    3.000000    1.000000    1.000000    0.498333
# 75%       0.000000    5.000000    1.000000    2.000000    0.655417
# max       1.000000    6.000000    1.000000    3.000000    0.861667
#
#              atemp         hum   windspeed       casual   registered  \
# count   731.000000  731.000000  731.000000   731.000000   731.000000
# unique         NaN         NaN         NaN          NaN          NaN
# top            NaN         NaN         NaN          NaN          NaN
# freq           NaN         NaN         NaN          NaN          NaN
# mean      0.474354    0.627894    0.190486   848.176471  3656.172367
# std       0.162961    0.142429    0.077498   686.622488  1560.256377
# min       0.079070    0.000000    0.022392     2.000000    20.000000
# 25%       0.337842    0.520000    0.134950   315.500000  2497.000000
# 50%       0.486733    0.626667    0.180975   713.000000  3662.000000
# 75%       0.608602    0.730209    0.233214  1096.000000  4776.500000
# max       0.840896    0.972500    0.507463  3410.000000  6946.000000
#
#                 cnt
# count    731.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    4504.348837
# std     1937.211452
# min       22.000000
# 25%     3152.000000
# 50%     4548.000000
# 75%     5956.000000
# max     8714.000000

# %%
df_day.instant.is_unique
# Out:
# True

# %%
df_day.instant.duplicated
# Out:
# <bound method Series.duplicated of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 726    727
# 727    728
# 728    729
# 729    730
# 730    731
# Name: instant, Length: 731, dtype: int64>

# %%
df_day.groupby(by="weekday").agg({
    "instant": "nunique",
    "mnth": ["max", "min", "mean", "std", ]
})
# Out:
#         instant mnth
#         nunique  max min      mean       std
# weekday
# 0           105   12   1  6.476190  3.483740
# 1           105   12   1  6.495238  3.494842
# 2           104   12   1  6.480769  3.450006
# 3           104   12   1  6.509615  3.435947
# 4           104   12   1  6.548077  3.455346
# 5           104   12   1  6.576923  3.443560
# 6           105   12   1  6.552381  3.497199

# %% [markdown]
# ### Menghubungkan Semua Data

# %%
all_df = pd.merge(
    left=df_hour,
    right=df_day,
    how="left",
)
all_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#             weather
# 0  Clear/Few Clouds
# 1  Clear/Few Clouds
# 2  Clear/Few Clouds
# 3  Clear/Few Clouds
# 4  Clear/Few Clouds

# %%
#Put it into .csv file
# Save the merged DataFrame to a CSV file
all_df.to_csv('merged_data.csv', index=False)

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# ### Insight: Weather Conditions vs. Total Bike Rentals - Day

# %%
# Assuming `data` is the original dataframe
# Map weather conditions to readable labels
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weather_mapping = {
    1: 'Clear/Few Clouds', 
    2: 'Mist/Cloudy', 
    3: 'Light Rain/Snow', 
    4: 'Heavy Rain/Snow'
}

# Apply the mapping directly to the 'weathersit' column
df_day['weather'] = df_day['weathersit'].map(weather_mapping)


# Create a box plot to show the distribution of bike rentals by weather condition
plt.figure(figsize=(10, 6))
sns.barplot(x='weather', y='cnt', data=df_day, palette="Set2")
plt.title('Bike Rentals by Weather Condition using Day Dataset')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Rentals')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_10511/529178392.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weather', y='cnt', data=df_day, palette="Set2")

# %% [markdown]
# ### Insight: Weather Conditions vs. Total Bike Rentals - Hou

# %%
# Assuming `data` is the original dataframe
# Map weather conditions to readable labels
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

weather_mapping = {
    1: 'Clear/Few Clouds', 
    2: 'Mist/Cloudy', 
    3: 'Light Rain/Snow', 
    4: 'Heavy Rain/Snow'
}

# Apply the mapping directly to the 'weathersit' column
df_hour['weather'] = df_hour['weathersit'].map(weather_mapping)


# Create a box plot to show the distribution of bike rentals by weather condition
plt.figure(figsize=(10, 6))
sns.barplot(x='weather', y='cnt', data=df_hour, palette="Set2")
plt.title('Bike Rentals by Weather Condition using Hour Dataset')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Rentals')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_10511/1321824926.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='weather', y='cnt', data=df_hour, palette="Set2")

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
